# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.set_style('darkgrid')

# %%
sns.set()
df = pd.read_csv('../data/raw/USA_cars_datasets.csv')
sns.heatmap(df.isnull(), cbar=False, yticklabels=False, cmap='viridis')
# Out:
# <AxesSubplot:>

# %% [markdown]
# From the above, we observe that there are no missing values in our dataset, had there been missing values, they would have been represented by different colors

# %%
df.shape
#So our data has 2499 observations and 13 features
# Out:
# (2499, 13)

# %% [markdown]
# **Let's get to know the data types of the various columns**

# %%
df.dtypes
# Out:
# Unnamed: 0        int64
# price             int64
# brand            object
# model            object
# year              int64
# title_status     object
# mileage         float64
# color            object
# vin              object
# lot               int64
# state            object
# country          object
# condition        object
# dtype: object

# %%
df.head()
#first 5 rows of our dataset
# Out:
#    Unnamed: 0  price      brand    model  year   title_status   mileage  \
# 0           0   6300     toyota  cruiser  2008  clean vehicle  274117.0
# 1           1   2899       ford       se  2011  clean vehicle  190552.0
# 2           2   5350      dodge      mpv  2018  clean vehicle   39590.0
# 3           3  25000       ford     door  2014  clean vehicle   64146.0
# 4           4  27700  chevrolet     1500  2018  clean vehicle    6654.0
#
#     color                  vin        lot       state country      condition
# 0   black    jtezu11f88k007763  159348797  new jersey     usa   10 days left
# 1  silver    2fmdk3gc4bbb02217  166951262   tennessee     usa    6 days left
# 2  silver    3c4pdcgg5jt346413  167655728     georgia     usa    2 days left
# 3    blue    1ftfw1et4efc23745  167753855    virginia     usa  22 hours left
# 4     red    3gcpcrec2jg473991  167763266     florida     usa  22 hours left

# %%
df.tail()
#last 5 rows of our dataset
# Out:
#       Unnamed: 0  price   brand  model  year   title_status  mileage   color  \
# 2494        2494   7800  nissan  versa  2019  clean vehicle  23609.0     red
# 2495        2495   9200  nissan  versa  2018  clean vehicle  34553.0  silver
# 2496        2496   9200  nissan  versa  2018  clean vehicle  31594.0  silver
# 2497        2497   9200  nissan  versa  2018  clean vehicle  32557.0   black
# 2498        2498   9200  nissan  versa  2018  clean vehicle  31371.0  silver
#
#                       vin        lot       state country      condition
# 2494    3n1cn7ap9kl880319  167722715  california     usa    1 days left
# 2495    3n1cn7ap5jl884088  167762225     florida     usa  21 hours left
# 2496    3n1cn7ap9jl884191  167762226     florida     usa  21 hours left
# 2497    3n1cn7ap3jl883263  167762227     florida     usa    2 days left
# 2498    3n1cn7ap4jl884311  167762228     florida     usa  21 hours left

# %%
df.sample(10)
# Out:
#       Unnamed: 0  price  brand    model  year       title_status   mileage  \
# 1236        1236   4200   ford     door  2013      clean vehicle       0.0
# 2197        2197  13600   ford   fusion  2019      clean vehicle   32154.0
# 1377        1377  18800   ford  mustang  2018      clean vehicle   41147.0
# 586          586  29900   ford    f-150  2019      clean vehicle   18759.0
# 1047        1047  17300  dodge  caravan  2019      clean vehicle   34407.0
# 143          143   7210  dodge    doors  2018      clean vehicle   38910.0
# 600          600  27102   ford    f-150  2019      clean vehicle   19100.0
# 1737        1737  46900   ford      max  2019      clean vehicle   41399.0
# 146          146   6800  dodge    doors  2018      clean vehicle   36767.0
# 1858        1858  15500   ford     door  2015  salvage insurance  131106.0
#
#          color                  vin        lot           state country  \
# ...

# %%
df.tail(10)
#To see the last 10 records
# Out:
#       Unnamed: 0  price   brand   model  year   title_status  mileage   color  \
# 2489        2489  13900  nissan   rogue  2018  clean vehicle  40259.0    gray
# 2490        2490  10400  nissan  sentra  2019  clean vehicle  25264.0    blue
# 2491        2491   9200  nissan   versa  2018  clean vehicle  35677.0   black
# 2492        2492   7400  nissan   versa  2019  clean vehicle  35511.0   black
# 2493        2493   9200  nissan   versa  2018  clean vehicle  33027.0   black
# 2494        2494   7800  nissan   versa  2019  clean vehicle  23609.0     red
# 2495        2495   9200  nissan   versa  2018  clean vehicle  34553.0  silver
# 2496        2496   9200  nissan   versa  2018  clean vehicle  31594.0  silver
# 2497        2497   9200  nissan   versa  2018  clean vehicle  32557.0   black
# 2498        2498   9200  nissan   versa  2018  clean vehicle  31371.0  silver
#
#                       vin        lot       state country      condition
# ...

# %%
df.describe()
#we want pandas to describe the numerical attributes of our dataset
# Out:
#         Unnamed: 0         price         year       mileage           lot
# count  2499.000000   2499.000000  2499.000000  2.499000e+03  2.499000e+03
# mean   1249.000000  18767.671469  2016.714286  5.229869e+04  1.676914e+08
# std     721.543484  12116.094936     3.442656  5.970552e+04  2.038772e+05
# min       0.000000      0.000000  1973.000000  0.000000e+00  1.593488e+08
# 25%     624.500000  10200.000000  2016.000000  2.146650e+04  1.676253e+08
# 50%    1249.000000  16900.000000  2018.000000  3.536500e+04  1.677451e+08
# 75%    1873.500000  25555.500000  2019.000000  6.347250e+04  1.677798e+08
# max    2498.000000  84900.000000  2020.000000  1.017936e+06  1.678055e+08

# %%
df.info()
#We want pandas to give us information about the categorical variables of our dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2499 entries, 0 to 2498
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    2499 non-null   int64
#  1   price         2499 non-null   int64
#  2   brand         2499 non-null   object
#  3   model         2499 non-null   object
#  4   year          2499 non-null   int64
#  5   title_status  2499 non-null   object
#  6   mileage       2499 non-null   float64
#  7   color         2499 non-null   object
#  8   vin           2499 non-null   object
#  9   lot           2499 non-null   int64
#  10  state         2499 non-null   object
#  11  country       2499 non-null   object
#  12  condition     2499 non-null   object
# dtypes: float64(1), int64(4), object(8)
# memory usage: 253.9+ KB

# %% [markdown]
# By the above information;
# 1.we can tell that all columns are non-null- which means that
# there are no empty or missing values in our dataset
# 2. Our dataset contains a float, 4 integer values and 8 objects

# %%
df.describe(include='object')
#summary statistics for categorical variables
# Out:
#        brand model   title_status  color                  vin         state  \
# count   2499  2499           2499   2499                 2499          2499
# unique    28   127              2     49                 2495            44
# top     ford  door  clean vehicle  white    1gnevhkw8jj148388  pennsylvania
# freq    1235   651           2336    707                    2           299
#
#        country    condition
# count     2499         2499
# unique       2           47
# top        usa  2 days left
# freq      2492          832

# %%
df.brand.unique()
#what are the various brands of cars in our dataset?
# Out:
# array(['toyota', 'ford', 'dodge', 'chevrolet', 'gmc', 'chrysler', 'kia',
#        'buick', 'infiniti', 'mercedes-benz', 'jeep', 'bmw', 'cadillac',
#        'hyundai', 'mazda', 'honda', 'heartland', 'jaguar', 'acura',
#        'harley-davidson', 'audi', 'lincoln', 'lexus', 'nissan', 'land',
#        'maserati', 'peterbilt', 'ram'], dtype=object)

# %%
df['brand'].value_counts()
#want to know how many cars we have for each brand
# Out:
# ford               1235
# dodge               432
# nissan              312
# chevrolet           297
# gmc                  42
# jeep                 30
# chrysler             18
# bmw                  17
# hyundai              15
# kia                  13
# buick                13
# infiniti             12
# honda                12
# cadillac             10
# mercedes-benz        10
# heartland             5
# land                  4
# peterbilt             4
# audi                  4
# acura                 3
# lincoln               2
# lexus                 2
# mazda                 2
# maserati              1
# toyota                1
# harley-davidson       1
# jaguar                1
# ram                   1
# Name: brand, dtype: int64

# %%
np.min(df.price)
#the minimum price you can enter when selecting a car
# Out:
# 0

# %%
np.max(df.price)
#The maximum price you can enter
# Out:
# 84900

# %%
df.year.unique()
# Out:
# array([2008, 2011, 2018, 2014, 2010, 2017, 2009, 2013, 2015, 2020, 2016,
#        1973, 2003, 2019, 2002, 2000, 2001, 2005, 2012, 2006, 2007, 1998,
#        2004, 1994, 1997, 1996, 1999, 1984, 1995, 1993], dtype=int64)

# %% [markdown]
# ## 10 Questions About Our Data

# %% [markdown]
# 1.Which top 5 models have the cheapest prices?

# %% [markdown]
# 2.

# %% [markdown]
# ## Inferences and Conclusion
