# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_style('darkgrid')

# %%
df=pd.read_csv('../data/raw/USA_cars_datasets.csv')

# %%
df.shape
#So our data has 2499 observations and 13 features
# Out:
# (2499, 13)

# %% [markdown]
# **Let's get to know the data types of the various columns**

# %%
df.dtypes
# Out:
# Unnamed: 0        int64
# price             int64
# brand            object
# model            object
# year              int64
# title_status     object
# mileage         float64
# color            object
# vin              object
# lot               int64
# state            object
# country          object
# condition        object
# dtype: object

# %%
df.head()
# Out:
#    Unnamed: 0  price      brand    model  year   title_status   mileage  \
# 0           0   6300     toyota  cruiser  2008  clean vehicle  274117.0
# 1           1   2899       ford       se  2011  clean vehicle  190552.0
# 2           2   5350      dodge      mpv  2018  clean vehicle   39590.0
# 3           3  25000       ford     door  2014  clean vehicle   64146.0
# 4           4  27700  chevrolet     1500  2018  clean vehicle    6654.0
#
#     color                  vin        lot       state country      condition
# 0   black    jtezu11f88k007763  159348797  new jersey     usa   10 days left
# 1  silver    2fmdk3gc4bbb02217  166951262   tennessee     usa    6 days left
# 2  silver    3c4pdcgg5jt346413  167655728     georgia     usa    2 days left
# 3    blue    1ftfw1et4efc23745  167753855    virginia     usa  22 hours left
# 4     red    3gcpcrec2jg473991  167763266     florida     usa  22 hours left

# %%
df.tail()
# Out:
#       Unnamed: 0  price   brand  model  year   title_status  mileage   color  \
# 2494        2494   7800  nissan  versa  2019  clean vehicle  23609.0     red
# 2495        2495   9200  nissan  versa  2018  clean vehicle  34553.0  silver
# 2496        2496   9200  nissan  versa  2018  clean vehicle  31594.0  silver
# 2497        2497   9200  nissan  versa  2018  clean vehicle  32557.0   black
# 2498        2498   9200  nissan  versa  2018  clean vehicle  31371.0  silver
#
#                       vin        lot       state country      condition
# 2494    3n1cn7ap9kl880319  167722715  california     usa    1 days left
# 2495    3n1cn7ap5jl884088  167762225     florida     usa  21 hours left
# 2496    3n1cn7ap9jl884191  167762226     florida     usa  21 hours left
# 2497    3n1cn7ap3jl883263  167762227     florida     usa    2 days left
# 2498    3n1cn7ap4jl884311  167762228     florida     usa  21 hours left

# %%
df.sample(10)
# Out:
#       Unnamed: 0  price      brand       model  year   title_status   mileage  \
# 898          898  14800      dodge     caravan  2017  clean vehicle   35991.0
# 1250        1250  38000       ford         srw  2019  clean vehicle   30018.0
# 1339        1339  57700       ford         srw  2019  clean vehicle   21101.0
# 2187        2187  28000       ford       wagon  2018  clean vehicle   22179.0
# 2295        2295   7800     nissan       versa  2018  clean vehicle   51552.0
# 1335        1335  44000       ford         srw  2019  clean vehicle   10763.0
# 1115        1115  17400      dodge     durango  2017  clean vehicle   89795.0
# 138          138  32012  chevrolet        1500  2017  clean vehicle   46091.0
# 704          704  12800  chevrolet        1500  2014  clean vehicle  177322.0
# 2055        2055  45000       ford  expedition  2019  clean vehicle   28790.0
#
#       color                  vin        lot         state country  \
# 898    gray    2c4rdgeg1hr716871  167493381       florida     usa
# 1250  white    1ft7w2bt4ked42668  167778307     minnesota     usa
# 1339    red    1ft7w2bt6kee59894  167738658      kentucky     usa
# 2187  black    1fbzx2xm1jka57423  167749406  pennsylvania     usa
# 2295    red    3n1cn7ap0jl821772  167724487    california     usa
# 1335  white    1ft7w2bt2ked42670  167780679      illinois     usa
# 1115    red    1c4rdjdgxhc847904  167628762      illinois     usa
# 138   white    3gcuksej6hg353147  167765148      michigan     usa
# 704   white    3gcuksej4eg356687  167790463         texas     usa
# 2055  black    1fmju2at8kea33665  167625637      illinois     usa
#
#           condition
# 898   23 hours left
# 1250    6 days left
# 1339  21 hours left
# 2187    2 days left
# 2295    2 days left
# 1335    2 days left
# 1115    2 days left
# 138     2 days left
# 704    7 hours left
# 2055    2 days left

# %%
df.tail(10)
#To see the last 10 records
# Out:
#       Unnamed: 0  price   brand   model  year   title_status  mileage   color  \
# 2489        2489  13900  nissan   rogue  2018  clean vehicle  40259.0    gray
# 2490        2490  10400  nissan  sentra  2019  clean vehicle  25264.0    blue
# 2491        2491   9200  nissan   versa  2018  clean vehicle  35677.0   black
# 2492        2492   7400  nissan   versa  2019  clean vehicle  35511.0   black
# 2493        2493   9200  nissan   versa  2018  clean vehicle  33027.0   black
# 2494        2494   7800  nissan   versa  2019  clean vehicle  23609.0     red
# 2495        2495   9200  nissan   versa  2018  clean vehicle  34553.0  silver
# 2496        2496   9200  nissan   versa  2018  clean vehicle  31594.0  silver
# 2497        2497   9200  nissan   versa  2018  clean vehicle  32557.0   black
# 2498        2498   9200  nissan   versa  2018  clean vehicle  31371.0  silver
#
#                       vin        lot       state country      condition
# 2489    knmat2mt9jp582734  167762219     florida     usa  21 hours left
# 2490    3n1ab7ap4ky323241  167722702  california     usa    1 days left
# 2491    3n1cn7ap7jl882312  167762221     florida     usa  21 hours left
# 2492    3n1cn7ap5kl841811  167722706  california     usa    1 days left
# 2493    3n1cn7ap0jl883768  167762224     florida     usa  21 hours left
# 2494    3n1cn7ap9kl880319  167722715  california     usa    1 days left
# 2495    3n1cn7ap5jl884088  167762225     florida     usa  21 hours left
# 2496    3n1cn7ap9jl884191  167762226     florida     usa  21 hours left
# 2497    3n1cn7ap3jl883263  167762227     florida     usa    2 days left
# 2498    3n1cn7ap4jl884311  167762228     florida     usa  21 hours left

# %%
df.describe()
# Out:
#         Unnamed: 0         price         year       mileage           lot
# count  2499.000000   2499.000000  2499.000000  2.499000e+03  2.499000e+03
# mean   1249.000000  18767.671469  2016.714286  5.229869e+04  1.676914e+08
# std     721.543484  12116.094936     3.442656  5.970552e+04  2.038772e+05
# min       0.000000      0.000000  1973.000000  0.000000e+00  1.593488e+08
# 25%     624.500000  10200.000000  2016.000000  2.146650e+04  1.676253e+08
# 50%    1249.000000  16900.000000  2018.000000  3.536500e+04  1.677451e+08
# 75%    1873.500000  25555.500000  2019.000000  6.347250e+04  1.677798e+08
# max    2498.000000  84900.000000  2020.000000  1.017936e+06  1.678055e+08

# %%
df.brand.unique()
#what are the various brands of cars in our dataset?
# Out:
# array(['toyota', 'ford', 'dodge', 'chevrolet', 'gmc', 'chrysler', 'kia',
#        'buick', 'infiniti', 'mercedes-benz', 'jeep', 'bmw', 'cadillac',
#        'hyundai', 'mazda', 'honda', 'heartland', 'jaguar', 'acura',
#        'harley-davidson', 'audi', 'lincoln', 'lexus', 'nissan', 'land',
#        'maserati', 'peterbilt', 'ram'], dtype=object)

# %%
df['brand'].value_counts()
#want to know how many cars we have for each brand
# Out:
# ford               1235
# dodge               432
# nissan              312
# chevrolet           297
# gmc                  42
# jeep                 30
# chrysler             18
# bmw                  17
# hyundai              15
# kia                  13
# buick                13
# infiniti             12
# honda                12
# cadillac             10
# mercedes-benz        10
# heartland             5
# land                  4
# peterbilt             4
# audi                  4
# acura                 3
# lincoln               2
# lexus                 2
# mazda                 2
# maserati              1
# toyota                1
# harley-davidson       1
# jaguar                1
# ram                   1
# Name: brand, dtype: int64

# %%
y=list(df.price)
plt.boxplot(y)
plt.show()

#want to use boxplot to see outliers in the various numeric attributes of our data

# %%
df.hist(figsize=(14,14),xrot=45)
plt.show()

# %%
np.min(df.price)
#the minimum cost of a car
# Out:
# 0

# %%
np.max(df.price)
#The maximum cost of a car
# Out:
# 84900

# %%
df.year.unique()
# Out:
# array([2008, 2011, 2018, 2014, 2010, 2017, 2009, 2013, 2015, 2020, 2016,
#        1973, 2003, 2019, 2002, 2000, 2001, 2005, 2012, 2006, 2007, 1998,
#        2004, 1994, 1997, 1996, 1999, 1984, 1995, 1993], dtype=int64)
